# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
import os
import numpy as np
import torch
import torchvision as tv
import torch.utils.data as td
import torch.nn.functional as F
from PIL import Image
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim

# %%
dataset_root_dir = 'BSDS300/images/'

# %%
os.listdir(dataset_root_dir)
# Out:
# ['.ipynb_checkpoints', 'train', 'test', 'Arbeit.ipynb']

# %%
class NoisyBSDSDataset(td.Dataset):
    def __init__(self,root_dir,mode='train',image_size=(180,180),sigma=30):
        super(NoisyBSDSDataset,self).__init__()
        self.mode = mode
        self.image_size = image_size
        self.sigma = sigma
        self.images_dir = os.path.join(root_dir,mode)
        self.files = os.listdir(self.images_dir)
        
    def __len__(self):
        return len(self.files)
    
    def __repr__(self):
        return f"NoisyBSDSDataset(mode={self.mode},image_size={self.image_size}, sigma={self.sigma})"
    
    
    def __getitem__(self,idx):
        img_path = os.path.join(self.images_dir,self.files[idx])
        clean = Image.open(img_path).convert('L')
        
         
        i = np.random.randint(clean.size[0]-self.image_size[0])
        j= np.random.randint(clean.size[1]-self.image_size[1])
        
        clean = clean.crop([i,j,i+self.image_size[0],j+self.image_size[1]])
        
        transform = tv.transforms.Compose([
            tv.transforms.ToTensor(),
            tv.transforms.Normalize((0.5,),(0.5,))
        ])
        clean = transform(clean)
        noisy = clean + 2/255 * self.sigma * torch.randn(clean.shape)
        return noisy,clean
    
    
train_set = NoisyBSDSDataset(root_dir= dataset_root_dir, mode='train', image_size = (180,180),sigma = 30)
test_set = NoisyBSDSDataset(root_dir = dataset_root_dir, mode= 'test', image_size = (320,320), sigma = 30)

# %%
train_set
# Out:
# NoisyBSDSDataset(mode=train,image_size=(180, 180), sigma=30)

# %%
def myimshow(image,ax = plt):
    image = image.numpy()
    image = np.moveaxis(image,[0,1,2],[2,0,1])
    image = (image+1)/2
    image[image<0] = 0
    image[image>1] = 1
    image =  ax.imshow(image,cmap='gray')
    ax.axis('off')
    return image

# %%
x = test_set[99]
fig,(ax1,ax2) = plt.subplots(ncols=2)
myimshow(x[0],ax = ax1)
myimshow(x[1], ax= ax2)

# %%
x[0].dtype
# Out:
# torch.float32

# %%
len(test_set)
# Out:
# 100

# %%
batch_size=16
train_loader = DataLoader(train_set,batch_size=batch_size,shuffle=True)
test_loader = DataLoader(test_set, batch_size=batch_size,shuffle=False)

# %%
class Denoising(nn.Module):
    def __init__(self,num_layers=25,c=64):
        super(Denoising,self).__init__()
        layers = []
        
        layers.append(nn.Conv2d(1,c,kernel_size=3,padding=1))
        layers.append(nn.ReLU())
        
        #intermediate layers
        
        for i in range(num_layers-2):
            layers.append(nn.Conv2d(c,c,kernel_size=3,padding=1))
            layers.append(nn.BatchNorm2d(c))
            layers.append(nn.ReLU())
            
        # final layer
        
        layers.append(nn.Conv2d(c,1,kernel_size=3,padding=1))
        self.dncnn = nn.Sequential(*layers)
        
    def forward(self,x):
        y = self.dncnn(x)+x
        return y

# %%
model = Denoising().to(device)
print(model)
# Out:
# Denoising(
#   (dncnn): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#     (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#     (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU()
#     (17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU()
#     (20): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU()
#     (23): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (25): ReLU()
#     (26): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (28): ReLU()
#     (29): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (31): ReLU()
#     (32): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (34): ReLU()
#     (35): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (36): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (37): ReLU()
#     (38): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (39): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (40): ReLU()
#     (41): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (42): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (43): ReLU()
#     (44): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (45): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (46): ReLU()
#     (47): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (48): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (49): ReLU()
#     (50): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (51): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (52): ReLU()
#     (53): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (54): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (55): ReLU()
#     (56): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (57): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (58): ReLU()
#     (59): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (60): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (61): ReLU()
#     (62): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (63): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (64): ReLU()
#     (65): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (66): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (67): ReLU()
#     (68): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (69): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (70): ReLU()
#     (71): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)
num_epochs = 100

# %%
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for (noisy, clean) in train_loader:
        noisy = noisy.to(device)
        clean = clean.to(device)
        optimizer.zero_grad()
        denoised = model(noisy)
        loss = criterion(denoised,clean)
        loss.backward()
        optimizer.step()
        running_loss+= loss.item()
        
    print(f"Epoch{epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader)}")
# Out:
# Epoch1/100, Loss: 0.11073792439240676
# Epoch2/100, Loss: 0.05650382317029513
# Epoch3/100, Loss: 0.05573635462384958
# Epoch4/100, Loss: 0.05550595974692932
# Epoch5/100, Loss: 0.05540283855337363
# Epoch6/100, Loss: 0.05540007782670168
# Epoch7/100, Loss: 0.05535195338038298
# Epoch8/100, Loss: 0.05544279802304048
# Epoch9/100, Loss: 0.05543437628791882
# Epoch10/100, Loss: 0.055414941161870956
# Epoch11/100, Loss: 0.05538893978183086
# Epoch12/100, Loss: 0.055378940529548205
# Epoch13/100, Loss: 0.05537197423669008
# Epoch14/100, Loss: 0.05534006225375029
# Epoch15/100, Loss: 0.05537256999657704
# Epoch16/100, Loss: 0.055339719813603624
# Epoch17/100, Loss: 0.05531215352507738
# Epoch18/100, Loss: 0.055370017886161804
# Epoch19/100, Loss: 0.05534101707430986
# Epoch20/100, Loss: 0.055358884999385245
# Epoch21/100, Loss: 0.05535018701965992
# Epoch22/100, Loss: 0.05523727347071354
# Epoch23/100, Loss: 0.055254386308101505
# Epoch24/100, Loss: 0.05509191149702439
# Epoch25/100, Loss: 0.05487954788483106
# Epoch26/100, Loss: 0.0546199232339859
# Epoch27/100, Loss: 0.053758074171268024
# Epoch28/100, Loss: 0.05124823061319498
# Epoch29/100, Loss: 0.04744602940403498
# Epoch30/100, Loss: 0.04280760053258676
# Epoch31/100, Loss: 0.03740624567637077
# Epoch32/100, Loss: 0.02799770164375122
# Epoch33/100, Loss: 0.01900906667399865
# Epoch34/100, Loss: 0.015375078082657777
# Epoch35/100, Loss: 0.014731387679393474
# Epoch36/100, Loss: 0.013572288748736564
# Epoch37/100, Loss: 0.012329847336961674
# Epoch38/100, Loss: 0.012289864512590261
# Epoch39/100, Loss: 0.012732514466803808
# Epoch40/100, Loss: 0.011769600857335787
# Epoch41/100, Loss: 0.011538432552837409
# Epoch42/100, Loss: 0.010868508225450149
# Epoch43/100, Loss: 0.011325940633049378
# Epoch44/100, Loss: 0.010454069178264875
# Epoch45/100, Loss: 0.010289954881255444
# Epoch46/100, Loss: 0.010118352607465707
# Epoch47/100, Loss: 0.00985942856193735
# Epoch48/100, Loss: 0.00987877374371657
# Epoch49/100, Loss: 0.009916875439767655
# Epoch50/100, Loss: 0.009670587543111581
# Epoch51/100, Loss: 0.009243739840502922
# Epoch52/100, Loss: 0.009406070798062362
# Epoch53/100, Loss: 0.009564109146595001
# Epoch54/100, Loss: 0.009422825649380684
# Epoch55/100, Loss: 0.009478864260017872
# Epoch56/100, Loss: 0.009431157225313095
# Epoch57/100, Loss: 0.009147039471337428
# Epoch58/100, Loss: 0.009277381325283876
# Epoch59/100, Loss: 0.009343789639667822
# Epoch60/100, Loss: 0.009358370604996499
# Epoch61/100, Loss: 0.00942778128844041
# Epoch62/100, Loss: 0.009019691926928667
# Epoch63/100, Loss: 0.009122169039283808
# Epoch64/100, Loss: 0.008837253249321993
# Epoch65/100, Loss: 0.008839866612106562
# Epoch66/100, Loss: 0.009046443021641327
# Epoch67/100, Loss: 0.009031152495971093
# Epoch68/100, Loss: 0.009104831036753379
# Epoch69/100, Loss: 0.00866065865669113
# Epoch70/100, Loss: 0.008936201902822806
# Epoch71/100, Loss: 0.008689237865977563
# Epoch72/100, Loss: 0.008767368307767006
# Epoch73/100, Loss: 0.008796346696236959
# Epoch74/100, Loss: 0.00891897827386856
# Epoch75/100, Loss: 0.00849739694967866
# Epoch76/100, Loss: 0.008612026138087878
# Epoch77/100, Loss: 0.009033162110986618
# Epoch78/100, Loss: 0.008638905182194252
# Epoch79/100, Loss: 0.008603986460142411
# Epoch80/100, Loss: 0.008839570988829318
# Epoch81/100, Loss: 0.008773785514327196
# Epoch82/100, Loss: 0.008664471061470417
# Epoch83/100, Loss: 0.0085148151892309
# Epoch84/100, Loss: 0.008496521578098718
# Epoch85/100, Loss: 0.008594846066374045
# Epoch86/100, Loss: 0.008659695776609274
# Epoch87/100, Loss: 0.008797226581149377
# Epoch88/100, Loss: 0.008744727175396223
# Epoch89/100, Loss: 0.008729514988282552
# Epoch90/100, Loss: 0.008486914914101362
# Epoch91/100, Loss: 0.00809127027885272
# Epoch92/100, Loss: 0.008797789064164344
# Epoch93/100, Loss: 0.008231077522325974
# Epoch94/100, Loss: 0.008309817514740504
# Epoch95/100, Loss: 0.008527323137968779
# Epoch96/100, Loss: 0.008488260925962375
# Epoch97/100, Loss: 0.008572261601399917
# Epoch98/100, Loss: 0.00843361378289186
# Epoch99/100, Loss: 0.008336533828137012
# Epoch100/100, Loss: 0.00849747396289156

# %%
model.eval()

def Show_Image(idx):
    noisy,clean = test_set[idx]
    noisy = noisy.to(device)
    clean = clean.to(device)
    
    with torch.no_grad():
        denoised = model(noisy.unsqueeze(0))[0]
        fig,axes = plt.subplots(ncols=3,nrows=1,figsize=(15,5),sharex= 'all',sharey = 'all')
        axes[0].set_title("Noisy")
        myimshow(noisy.cpu(),axes[0])
        
        axes[1].set_title("Clean")
        myimshow(clean.cpu(),axes[1])
        
        axes[2].set_title("Denoised")
        myimshow(denoised.cpu(),axes[2])

# %%
Show_Image(25)
plt.savefig('tiger.png')

# %%
num_gpus = torch.cuda.device_count()

# %%
num_gpus

# %%
current_device = torch.cuda.current_device()
current_device

# %%
x = test_set[25]

# %%
x[0].shape

# %%
x[0]

# %%
aloc_mem=torch.cuda.memory_allocated()
print(f"Currently allocated GPU memory: {aloc_mem / 1024**2} MB")

# %%
peak_memory = torch.cuda.max_memory_allocated()
print(f"Peak GPU memory usage: {peak_memory / 1024**2} MB")
